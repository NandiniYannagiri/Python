# %% [markdown]
# ### Snake game

# %%
import random
roll = 0
count = 0
while True:
    input("click enter button to roll dice.....")
    dice = random.randint(1,6)
    print(f"current dice value {dice}")
    if count+dice<=100:
        count+=dice
    roll+=1
    if count==100:
        print(f"you reach top in {roll} rolls")
        break
    print(f"For {roll} rolls you are at {count} position")
# Out:
# click enter button to roll dice.....
# current dice value 3
# For 1 rolls you are at 3 position
# click enter button to roll dice.....
# current dice value 5
# For 2 rolls you are at 8 position
# click enter button to roll dice.....
# current dice value 5
# For 3 rolls you are at 13 position
# click enter button to roll dice.....
# current dice value 4
# For 4 rolls you are at 17 position
# click enter button to roll dice.....
# current dice value 2
# For 5 rolls you are at 19 position
# click enter button to roll dice.....
# current dice value 5
# For 6 rolls you are at 24 position
# click enter button to roll dice.....
# current dice value 6
# For 7 rolls you are at 30 position
# click enter button to roll dice.....
# current dice value 5
# For 8 rolls you are at 35 position
# click enter button to roll dice.....
# current dice value 4
# For 9 rolls you are at 39 position
# click enter button to roll dice.....
# current dice value 4
# For 10 rolls you are at 43 position
# click enter button to roll dice.....
# current dice value 6
# For 11 rolls you are at 49 position
# click enter button to roll dice.....
# current dice value 1
# For 12 rolls you are at 50 position
# click enter button to roll dice.....
# current dice value 3
# For 13 rolls you are at 53 position
# click enter button to roll dice.....
# current dice value 3
# For 14 rolls you are at 56 position
# click enter button to roll dice.....
# current dice value 3
# For 15 rolls you are at 59 position
# click enter button to roll dice.....
# current dice value 6
# For 16 rolls you are at 65 position
# click enter button to roll dice.....
# current dice value 4
# For 17 rolls you are at 69 position
# click enter button to roll dice.....
# current dice value 6
# For 18 rolls you are at 75 position
# click enter button to roll dice.....
# current dice value 6
# For 19 rolls you are at 81 position
# click enter button to roll dice.....
# current dice value 4
# For 20 rolls you are at 85 position
# click enter button to roll dice.....
# current dice value 3
# For 21 rolls you are at 88 position
# click enter button to roll dice.....
# current dice value 4
# For 22 rolls you are at 92 position
# click enter button to roll dice.....
# current dice value 5
# For 23 rolls you are at 97 position
# click enter button to roll dice.....
# current dice value 5
# For 24 rolls you are at 97 position
# click enter button to roll dice.....
# current dice value 2
# For 25 rolls you are at 99 position
# click enter button to roll dice.....
# current dice value 4
# For 26 rolls you are at 99 position
# click enter button to roll dice.....
# current dice value 5
# For 27 rolls you are at 99 position
# click enter button to roll dice.....
# current dice value 1
# you reach top in 28 rolls

# %% [markdown]
# ### Stop Watch

# %%
import time
print("Hi....")
time.sleep(5)
print("Hello..")
# Out:
# Hi....
# Hello..

# %% [markdown]
# ### Time

# %%
from IPython.display import clear_output
seconds = 0
minutes = 0
hours = 0
while True:
    print(f"{hours}:{minutes}:{seconds}")
    time.sleep(1)
    seconds +=1
    if seconds==60:
        minutes+=1
        seconds = 0
        if minutes==60:
            hours+=1
            minutes = 0
    clear_output(wait = True)
# Out:
# 0:4:34

# %% [markdown]
# ### Random Password Generator

# %%
import random
upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
lower = "abcdefghijklmnopqrstuvwxyz"
digits = "0123456789"
special = "!@#$%^&*"
length = int(input("Enter password length: "))
if length < 4:
    print("Password length must be at least 4")
else:
    password = [random.choice(upper),
        random.choice(lower),
        random.choice(digits),
        random.choice(special)]
    all_characters = upper + lower + digits + special
    password += random.sample(all_characters, length - 4)
    random.shuffle(password)
    password = "".join(password)
    print("Generated Password:", password)
# Out:
# Enter password length:  8
# Generated Password: $SmA65s2

# %%
# only gives 8 characters
all_characters = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789!@#$%^&*"
p = random.sample(all_characters,8)
password = "".join(p)
print(password)
# Out:
# b#R0t3Gg

# %% [markdown]
# ### ATM Application

# %%
import random
balance = 10000
# Generate a 4-digit PIN
pin = random.randint(1000, 9999)
print("Your ATM PIN is:", pin)
entered_pin = int(input("Enter your PIN: "))
if entered_pin == pin:
    while True:
        print("\n===== ATM MENU =====")
        print("1. Check Balance")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Exit")
        choice = int(input("Enter your choice: "))
        if choice == 1:
            print("Your balance is: ₹", balance)
        elif choice == 2:
            amount = float(input("Enter deposit amount: ₹"))
            if amount > 0:
                balance += amount
                print("Deposit successful!")
                print("New balance: ₹", balance)
            else:
                print("Invalid amount.")
        elif choice == 3:
            amount = float(input("Enter withdrawal amount: ₹"))
            if amount > balance:
                print("Insufficient balance.")
            elif amount <= 0:
                print("Invalid amount.")
            else:
                balance -= amount
                print("Please collect your cash.")
                print("Remaining balance: ₹", balance)
        elif choice == 4:
            print("Thank you for using the ATM!")
            break
        else:
            print("Invalid choice.")
else:
    print("Incorrect PIN!")
# Out:
# Your ATM PIN is: 1109
# Enter your PIN:  1109
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice:  1
# Your balance is: ₹ 10000
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice:  2
# Enter deposit amount: ₹ 2000
# Deposit successful!
# New balance: ₹ 12000.0
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice:  3
# Enter withdrawal amount: ₹ 500
# Please collect your cash.
# Remaining balance: ₹ 11500.0
#
# ===== ATM MENU =====
# 1. Check Balance
# 2. Deposit
# 3. Withdraw
# 4. Exit
# Enter your choice:  4
# Thank you for using the ATM!
